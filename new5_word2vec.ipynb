# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch  = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j,0] = buffer[skip_window]
      labels[i * num_skips + j] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:10]])

for num_skips, skip_window in [(1, 3), (1, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8)])
    print('    labels:', [reverse_dictionary[li] for li in labels])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with num_skips = 1 and skip_window = 3:
#     batch: ['a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early']
#     labels: ['anarchism', 'abuse', 'first', 'used', 'abuse', 'against', 'first', 'first']
#
# with num_skips = 1 and skip_window = 2:
#     batch: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#     labels: ['term', 'term', 'a', 'a', 'term', 'used', 'against', 'working']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128*2 # Dimension of the embedding vector.
skip_window = 4 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 300 # Only pick dev samples in the middle of the distribution.
valid_examples = np.array(random.sample(range(100,valid_window), valid_size))
num_sampled = 32*2 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 80001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_labels, batch_data = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.031660
# Nearest to term: cochin, ven, replicating, meiosis, purgatory, ralph, antigens, accommodations,
# Nearest to north: anthropic, administrated, vices, zhuhai, lindisfarne, cooperatively, yoannis, anglo,
# Nearest to modern: fem, bulls, bucaram, epimenides, tubular, compass, subjugating, custis,
# Nearest to end: excavated, utrecht, instance, mourns, epidemiology, objectors, carrion, irrevocably,
# Nearest to each: gly, mensch, tundra, muad, why, pleasures, rnir, quartet,
# Nearest to water: meditate, unsympathetic, vermilion, silenced, mgh, efficiency, vestal, exponents,
# Nearest to order: catalans, reiterated, reviewed, tao, murbella, guttural, barthes, nasser,
# Nearest to control: godwin, assumed, tosefta, fonts, including, jacketed, dissipated, jackal,
# Nearest to left: intruders, napoleon, patria, realities, divination, dhole, semantic, fissile,
# Nearest to written: goofy, fabricius, alh, hungary, immunities, bicycles, remembered, rollers,
# Nearest to series: telegram, resemble, corporal, cops, gisela, hampshire, endl, snowstorm,
# Nearest to external: deum, speeding, gladiators, shimbun, punks, kylix, propagating, inspiration,
# Nearest to last: cougars, bombed, demons, unnecessary, nameserver, demography, ptolemaic, grandmasters,
# Nearest to another: readable, kilby, horowitz, elaborately, iom, slaughter, sons, inhibitory,
# Nearest to british: parsecs, strong, sloping, two, derby, dyess, intron, unwilling,
# Nearest to union: biplane, cordwainer, pretending, es, simmered, netherland, caulfield, wondering,
# Average loss at step 2000: 4.805799
# Average loss at step 4000: 4.372370
# Average loss at step 6000: 4.209117
# Average loss at step 8000: 4.208360
# Average loss at step 10000: 4.058174
# Nearest to term: ven, cochin, replicating, whisper, purgatory, firmer, antigens, elizabethan,
# Nearest to north: administrated, in, anthropic, lindisfarne, vices, anglo, cooperatively, zhuhai,
# Nearest to modern: bulls, fem, implications, natchez, custis, carpenters, abt, epimenides,
# Nearest to end: excavated, instance, mourns, granted, epidemiology, crystallized, broadly, common,
# Nearest to each: mensch, rnir, do, rubies, quartet, why, tundra, overlooking,
# Nearest to water: meditate, address, silenced, nerves, efficiency, unsympathetic, mgh, activities,
# Nearest to order: reviewed, barthes, catalans, guttural, bottomed, tao, kinetoscope, austere,
# Nearest to control: godwin, including, assumed, tosefta, cities, arin, fonts, sgt,
# Nearest to left: intruders, napoleon, seated, patria, realities, divination, fry, fissile,
# Nearest to written: goofy, bicycles, pointy, rollers, hungary, immunities, charleston, fabricius,
# Nearest to series: telegram, gisela, nicolas, cops, hampshire, resemble, fortunes, relates,
# Nearest to external: deum, gladiators, speeding, inspiration, gustavus, punks, hewlett, counters,
# Nearest to last: cougars, bombed, demons, nameserver, demography, unnecessary, grandmasters, ruptured,
# Nearest to another: horowitz, kilby, readable, elaborately, iom, sons, wiles, slaughter,
# Nearest to british: parsecs, strong, budweiser, illusions, unwilling, litas, northerners, identifier,
# Nearest to union: cordwainer, biplane, pretending, simmered, es, dizzy, ebu, caulfield,
# Average loss at step 12000: 4.099907
# Average loss at step 14000: 4.073915
# Average loss at step 16000: 4.065360
# Average loss at step 18000: 3.754706
# Average loss at step 20000: 3.813156
# Nearest to term: cochin, ven, trigonometric, firmer, virgo, embarrassed, meiosis, antigens,
# Nearest to north: administrated, anglo, anthropic, vices, zhuhai, lindisfarne, borderline, keywork,
# Nearest to modern: bulls, implications, natchez, carpenters, fem, transsexuals, lunches, thoroughly,
# Nearest to end: excavated, instance, mourns, crystallized, common, irrevocably, utrecht, suffixes,
# Nearest to each: do, mensch, rubies, rnir, why, specialized, fungus, gly,
# Nearest to water: meditate, address, efficiency, vermilion, silenced, unsympathetic, vestal, mgh,
# Nearest to order: reviewed, escape, tao, immediate, kinetoscope, barthes, austere, nasa,
# Nearest to control: godwin, including, cities, assumed, arin, dissipated, tosefta, fonts,
# Nearest to left: intruders, napoleon, seated, patria, realities, encased, fry, welling,
# Nearest to written: goofy, pointy, bicycles, immunities, resemblance, rollers, charleston, hungary,
# Nearest to series: gisela, telegram, nicolas, fortunes, relates, celtic, simulating, hampshire,
# Nearest to external: deum, gladiators, punks, peasant, ape, speeding, seceded, hewlett,
# Nearest to last: cougars, bombed, unnecessary, demons, minstrel, nameserver, when, demography,
# Nearest to another: kilby, horowitz, readable, elaborately, sons, meritorious, iom, jainism,
# Nearest to british: northerners, parsecs, strong, budweiser, illusions, begins, longford, one,
# Nearest to union: cordwainer, biplane, simmered, pretending, caulfield, es, ebu, dizzy,
# Average loss at step 22000: 3.817157
# Average loss at step 24000: 3.952942
# Average loss at step 26000: 4.003711
# Average loss at step 28000: 3.991842
# Average loss at step 30000: 3.958206
# Nearest to term: cochin, ven, firmer, meiosis, embarrassed, virgo, replicating, trigonometric,
# Nearest to north: anglo, administrated, anthropic, vices, macrinus, east, zhuhai, borderline,
# Nearest to modern: implications, bulls, abt, carpenters, lunches, natchez, interwar, epimenides,
# Nearest to end: instance, excavated, mourns, arpanet, irrevocably, cei, subversion, sideways,
# Nearest to each: do, rnir, specialized, gly, why, mensch, abusers, bullock,
# Nearest to water: meditate, address, efficiency, vestal, nerves, unsympathetic, silenced, broz,
# Nearest to order: day, kinetoscope, bottomed, reviewed, nasa, tao, escape, immediate,
# Nearest to control: godwin, cities, tosefta, assumed, arin, dissipated, including, jacketed,
# Nearest to left: seated, intruders, napoleon, patria, realities, encased, fry, margins,
# Nearest to written: goofy, pointy, reasonable, resemblance, bicycles, fabricius, shackleton, remembered,
# Nearest to series: gisela, telegram, hampshire, nicolas, celtic, knute, promotes, taunting,
# Nearest to external: ape, gustavus, seceded, deum, gladiators, asperger, punks, hewlett,
# Nearest to last: unnecessary, cougars, when, minstrel, nameserver, demons, ruptured, bombed,
# Nearest to another: kilby, horowitz, readable, elaborately, meritorious, iom, caveats, jainism,
# Nearest to british: northerners, litas, parsecs, american, strong, illusions, expressway, begins,
# Nearest to union: cordwainer, biplane, caulfield, pretending, simmered, warranties, symbolising, es,
# Average loss at step 32000: 4.012305
# Average loss at step 34000: 4.038966
# Average loss at step 36000: 4.001751
# Average loss at step 38000: 4.024933
# Average loss at step 40000: 3.830072
# Nearest to term: cochin, ven, embarrassed, firmer, tenochtitlan, virgo, meiosis, cylinder,
# Nearest to north: east, administrated, anglo, baptisms, keywork, anthropic, lindisfarne, jay,
# Nearest to modern: implications, bulls, carpenters, natchez, ammianus, thoroughly, list, abt,
# Nearest to end: instance, knights, mourns, misuse, sideways, irrevocably, cei, excavated,
# Nearest to each: why, specialized, gly, do, overlooking, rnir, abodes, abusers,
# Nearest to water: meditate, address, nerves, specific, competency, efficiency, retook, paths,
# Nearest to order: day, escape, unpublished, nasa, immediate, tao, kinetoscope, reviewed,
# Nearest to control: godwin, cities, assumed, arin, tackling, tosefta, including, duel,
# Nearest to left: seated, fry, intruders, gulch, napoleon, patria, realities, redrawn,
# Nearest to written: reasonable, goofy, remembered, pointy, bicycles, resemblance, abstaining, clan,
# Nearest to series: gisela, telegram, hampshire, weser, knute, endl, clog, celtic,
# Nearest to external: links, ape, asperger, also, deum, gustavus, metaphysical, freie,
# Nearest to last: cougars, unnecessary, over, ruptured, minstrel, demons, gotlanders, realisation,
# Nearest to another: kilby, readable, meritorious, horowitz, elaborately, jainism, iom, buddha,
# Nearest to british: northerners, litas, american, expressway, begins, longford, illusions, parsecs,
# Nearest to union: cordwainer, biplane, pretending, caulfield, simmered, warranties, symbolising, ebu,
# Average loss at step 42000: 3.968998
# Average loss at step 44000: 3.952559
# Average loss at step 46000: 3.953019
# Average loss at step 48000: 3.951833
# Average loss at step 50000: 4.002293
# Nearest to term: cochin, embarrassed, virgo, lubavitch, meiosis, ven, firmer, tenochtitlan,
# Nearest to north: east, the, anglo, anthropic, jay, largest, kosova, macrinus,
# Nearest to modern: implications, bulls, carpenters, smokeless, interwar, repetitions, unforgettable, ammianus,
# Nearest to end: instance, knights, rarities, subversion, sideways, misuse, irrevocably, mourns,
# Nearest to each: specialized, rnir, overlooking, do, gly, why, rubies, abusers,
# Nearest to water: meditate, exponents, dhcp, efficiency, specific, unsympathetic, nerves, competency,
# Nearest to order: escape, unpublished, stacking, reiterated, too, bottomed, tao, immediate,
# Nearest to control: godwin, arin, cities, tackling, tosefta, assumed, fonts, duel,
# Nearest to left: right, intruders, fry, seated, realities, gulch, intended, conveying,
# Nearest to written: reasonable, remembered, pointy, bicycles, goofy, abstaining, gh, resemblance,
# Nearest to series: logos, gisela, weser, brun, hampshire, endl, knute, relates,
# Nearest to external: links, ape, asperger, information, gustavus, metaphysical, web, site,
# Nearest to last: cougars, minstrel, unnecessary, demons, realisation, same, vesalius, demography,
# Nearest to another: kilby, readable, meritorious, horowitz, elaborately, iom, buddha, conversion,
# Nearest to british: american, northerners, qinghai, expressway, litas, budweiser, lord, begins,
# Nearest to union: cordwainer, biplane, caulfield, pretending, symbolising, warranties, ria, elected,
# Average loss at step 52000: 3.936997
# Average loss at step 54000: 3.838401
# Average loss at step 56000: 3.777956
# Average loss at step 58000: 3.871756
# Average loss at step 60000: 3.925847
# Nearest to term: embarrassed, ven, purgatory, firmer, it, cochin, whisper, meiosis,
# Nearest to north: east, west, south, zhuhai, anglo, jay, anthropic, kosova,
# Nearest to modern: implications, many, bulls, thoroughly, smokeless, list, interwar, repetitions,
# Nearest to end: time, knights, instance, subversion, misuse, mourns, ineffective, inadvertent,
# Nearest to each: specialized, single, a, rnir, every, gly, explanation, overlooking,
# Nearest to water: meditate, range, requesting, dhcp, efficiency, symptomatic, nerves, vestal,
# Nearest to order: escape, newsreels, beachcomber, too, immediate, navel, unpublished, ursa,
# Nearest to control: godwin, tackling, tosefta, fonts, cities, arin, duel, assumed,
# Nearest to left: right, intruders, realities, seated, fry, pic, ethno, semantic,
# Nearest to written: reasonable, goofy, remembered, abstaining, pointy, bicycles, clan, rassemblement,
# Nearest to series: hampshire, brun, weser, gisela, endl, taunting, knute, laurentiis,
# Nearest to external: links, see, ape, list, information, site, bbc, gustavus,
# Nearest to last: cougars, unnecessary, minstrel, demons, first, same, demography, globe,
# Nearest to another: meritorious, kilby, elaborately, readable, horowitz, conversion, buddha, iom,
# Nearest to british: american, english, northerners, expressway, three, qinghai, nine, lord,
# Nearest to union: cordwainer, warranties, biplane, caulfield, symbolising, pretending, elected, simmered,
# Average loss at step 62000: 3.864546
# Average loss at step 64000: 3.955496
# Average loss at step 66000: 3.943846
# Average loss at step 68000: 3.887644
# Average loss at step 70000: 3.827509
# Nearest to term: firmer, lubavitch, ven, momentum, elegans, purgatory, whisper, virgo,
# Nearest to north: east, south, west, zhuhai, largest, resolvers, anthropic, bind,
# Nearest to modern: implications, vaishnavism, many, lunches, music, unforgettable, smokeless, demarco,
# Nearest to end: time, subversion, instance, knights, rarities, misuse, acyclic, during,
# Nearest to each: a, specialized, single, rnir, gly, every, why, vase,
# Nearest to water: meditate, range, nerves, efficiency, vestal, dhcp, requesting, symptomatic,
# Nearest to order: newsreels, unpublished, escape, rainbow, without, navel, dualist, beachcomber,
# Nearest to control: tackling, tosefta, godwin, cities, assumed, processing, andaman, arin,
# Nearest to left: right, intruders, realities, gulch, transgender, fry, pic, archivers,
# Nearest to written: abstaining, reasonable, pointy, bicycles, rassemblement, remembered, goofy, fabricius,
# Nearest to series: brun, on, hampshire, gisela, game, relates, taunting, knute,
# Nearest to external: links, see, ape, information, official, asperger, site, gustavus,
# Nearest to last: cougars, first, minstrel, unnecessary, demons, gcc, huntley, vesalius,
# Nearest to another: meritorious, horowitz, a, conversion, readable, elaborately, kilby, s,
# Nearest to british: american, english, northerners, lord, qinghai, abbas, tony, litas,
# Nearest to union: cordwainer, biplane, warranties, symbolising, caulfield, espace, simmered, faber,
# Average loss at step 72000: 3.934836
# Average loss at step 74000: 3.972800
# Average loss at step 76000: 3.974420
# Average loss at step 78000: 3.907029
# Average loss at step 80000: 3.905842
# Nearest to term: firmer, purgatory, ven, ornithology, precarious, lubavitch, elegans, cylinder,
# Nearest to north: south, east, west, western, southern, central, largest, voids,
# Nearest to modern: implications, many, some, history, lunches, demarco, interwar, list,
# Nearest to end: time, instance, subversion, after, lungs, disappointment, until, acyclic,
# Nearest to each: single, specialized, rnir, gly, abusers, why, glosses, celts,
# Nearest to water: meditate, range, vestal, exponents, specific, nerves, efficiency, dhcp,
# Nearest to order: channels, newsreels, without, gravesite, measured, escape, sola, ursa,
# Nearest to control: tosefta, tackling, godwin, assumed, aesthetic, craton, fonts, meaningfully,
# Nearest to left: right, t, intruders, realities, freshness, lim, frac, fry,
# Nearest to written: english, abstaining, pointy, bicycles, remembered, goofy, furthest, rassemblement,
# Nearest to series: brun, game, gisela, parabola, communicating, saladin, knute, hampshire,
# Nearest to external: links, information, see, ape, official, list, site, com,
# Nearest to last: first, cougars, after, demons, vesalius, gcc, minstrel, during,
# Nearest to another: meritorious, conversion, readable, brightly, elaborately, bautista, iom, jainism,
# Nearest to british: american, northerners, tony, led, litas, soviet, abbas, institutions,
# Nearest to union: cordwainer, biplane, warranties, symbolising, caulfield, espace, faber, christina,

# %%
num_points = 500
start = 0
num_pointss = num_points+start

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[start:num_pointss+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# I basically just changed the labels with the data, boom, cbow, I hope
