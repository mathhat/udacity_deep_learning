# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create an LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# 11
# (64, 27)
# (64, 27)

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
    
  sx = tf.concat([ix,fx,cx,ox],1)
  sm = tf.concat([im,fm,cm,om],1)
  sb = tf.concat([ib,fb,cb,ob],1)

  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    concat_gates = tf.matmul(i,sx) + tf.matmul(o,sm) + sb    
    input_gate,forget_gate,update,output_gate = tf.split(concat_gates,4,1)
    
    
    input_gate  = tf.sigmoid(input_gate)
    forget_gate = tf.sigmoid(forget_gate)
    output_gate = tf.sigmoid(output_gate)
    #update = #tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train an LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %%
num_nodes = 64*2
embedding_dim = 32*3
drop_prob = 0.80

graph = tf.Graph()
print(vocabulary_size)
with graph.as_default():
  
  # Parameters:
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size*vocabulary_size, embedding_dim], -0.5, 0.5))
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_dim, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_dim, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_dim, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_dim, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  sx = tf.concat([ix,fx,cx,ox],1)
  sm = tf.concat([im,fm,cm,om],1)
  sb = tf.concat([ib,fb,cb,ob],1)

  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    concat_gates = tf.matmul(i,sx) + tf.matmul(o,sm) + sb    
    input_gate,forget_gate,update,output_gate = tf.split(concat_gates,4,1)
    
    
    input_gate  = tf.sigmoid(input_gate)
    forget_gate = tf.sigmoid(forget_gate)
    output_gate = tf.sigmoid(output_gate)
    #update = #tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_chars = train_data[:num_unrollings]
  train_inputs = zip(train_chars[:-1],train_chars[1:])
  print (train_inputs)
  train_labels = train_data[2:]  # labels are inputs shifted by one time step.
  print (train_labels)
  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    i_embed = tf.nn.embedding_lookup(embeddings, tf.argmax(i[0], axis=1) + vocabulary_size*tf.argmax(i[1], axis=1))
    i_embed = tf.nn.dropout(i_embed,drop_prob)
    output, state = lstm_cell(i_embed, output, state)
    outputs.append(output)
  print (outputs)


  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    logits = tf.nn.dropout(logits,drop_prob)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 1500, 0.6, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = list()
  for _ in range(2):
    sample_input.append(tf.placeholder(tf.float32, shape=[1, vocabulary_size]))
  sample_input_embedding = tf.nn.embedding_lookup(embeddings, tf.argmax(sample_input[0], axis=1)+ tf.argmax(sample_input[1], axis=1)*vocabulary_size)
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
# Out:
# 27
# [(<tf.Tensor 'Placeholder:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_1:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_1:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_2:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_2:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_3:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_3:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_4:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_4:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_5:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_5:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_6:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_6:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_7:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_7:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_8:0' shape=(64, 27) dtype=float32>), (<tf.Tensor 'Placeholder_8:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_9:0' shape=(64, 27) dtype=float32>)]
# [<tf.Tensor 'Placeholder_2:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_3:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_4:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_5:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_6:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_7:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_8:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_9:0' shape=(64, 27) dtype=float32>, <tf.Tensor 'Placeholder_10:0' shape=(64, 27) dtype=float32>]
# [<tf.Tensor 'mul_3:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_7:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_11:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_15:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_19:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_23:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_27:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_31:0' shape=(64, 128) dtype=float32>, <tf.Tensor 'mul_35:0' shape=(64, 128) dtype=float32>]

# %%
import collections
num_steps = 9001
summary_frequency = 100
valid_batches = BatchGenerator(valid_text, 1, 2)
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency*3 == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[2:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = collections.deque(maxlen=2)
          for _ in range(2):  
            feed.append(random_distribution())
          #feed = sample(random_distribution())
          #sentence = characters(feed)[0]
          sentence = characters(feed[0])[0] + characters(feed[1])[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input[0]: feed[0],sample_input[1]: feed[1]})
            #feed = sample(prediction)
            feed.append(sample(prediction))
            sentence += characters(feed[1])[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input[0]: b[0],sample_input[1]: b[1]})
        valid_logprob = valid_logprob + logprob(predictions, b[2])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.617076 learning rate: 10.000000
# Minibatch perplexity: 37.23
# ================================================================================
# otav cjnjoq u uszm hxf aicaswv sws  s nltena pjsmosr gt s qr w l  kcmb oa guduham
#   ezn mmya ynbofj lr kio  ac nph fhcma rznlqq z bigse js mmd mteljj  f fft  gcgtn
# rjdor azlwsdnie lso fc ye ovu cyepnamd ifpzni rafmcxhae ahd i ooqsswswwv zq vazix
# j nes nvq ll yqgra  yy nd dpd bsarvw ya p xheaw xxrvd  b dmr kntciey eyrytieu s b
# qpks  oldvhxw nn xmtflw ablkh  exjhet al a pn g  p li waev tqhsrbmcia rocqpqkvlsp
# ================================================================================
# Validation set perplexity: 24.61
# Average loss at step 100: 2.751913 learning rate: 10.000000
# Minibatch perplexity: 14.04
# Validation set perplexity: 11.57
# Average loss at step 200: 2.405346 learning rate: 10.000000
# Minibatch perplexity: 9.17
# Validation set perplexity: 9.49
# Average loss at step 300: 2.265226 learning rate: 10.000000
# Minibatch perplexity: 8.44
# Validation set perplexity: 8.77
# Average loss at step 400: 2.207596 learning rate: 10.000000
# Minibatch perplexity: 8.14
# Validation set perplexity: 8.44
# Average loss at step 500: 2.207532 learning rate: 10.000000
# Minibatch perplexity: 8.39
# Validation set perplexity: 8.16
# Average loss at step 600: 2.149390 learning rate: 10.000000
# Minibatch perplexity: 8.43
# Validation set perplexity: 8.01
# Average loss at step 700: 2.126392 learning rate: 10.000000
# Minibatch perplexity: 8.29
# Validation set perplexity: 7.73
# Average loss at step 800: 2.110107 learning rate: 10.000000
# Minibatch perplexity: 8.65
# Validation set perplexity: 7.43
# Average loss at step 900: 2.098247 learning rate: 10.000000
# Minibatch perplexity: 6.70
# Validation set perplexity: 7.62
# Average loss at step 1000: 2.045693 learning rate: 10.000000
# Minibatch perplexity: 7.88
# ================================================================================
# sative and the wrine sign these natps roking the everm to egal antor if than ary
# g seats rtf deverthe net people with synebptian of is arfaabeaub instruually kimp
# vvture a nottee upilar had multenceure eight nover includes additic american cogn
# qgational to yantillekracity a formean also bazimerabete of deiffentabn wal woric
# egrate socifies two zero see balgaarh awas hee power ar our verse film commended
# ================================================================================
# Validation set perplexity: 7.30
# Average loss at step 1100: 2.021085 learning rate: 10.000000
# Minibatch perplexity: 8.17
# Validation set perplexity: 7.72
# Average loss at step 1200: 2.047535 learning rate: 10.000000
# Minibatch perplexity: 8.27
# Validation set perplexity: 7.48
# Average loss at step 1300: 2.036056 learning rate: 10.000000
# Minibatch perplexity: 7.34
# Validation set perplexity: 7.38
# Average loss at step 1400: 2.007894 learning rate: 10.000000
# Minibatch perplexity: 7.14
# Validation set perplexity: 7.32
# Average loss at step 1500: 2.012784 learning rate: 6.000000
# Minibatch perplexity: 8.98
# Validation set perplexity: 7.19
# Average loss at step 1600: 1.980229 learning rate: 6.000000
# Minibatch perplexity: 6.63
# Validation set perplexity: 7.19
# Average loss at step 1700: 2.000803 learning rate: 6.000000
# Minibatch perplexity: 8.19
# Validation set perplexity: 7.16
# Average loss at step 1800: 1.973834 learning rate: 6.000000
# Minibatch perplexity: 7.05
# Validation set perplexity: 6.95
# Average loss at step 1900: 1.972658 learning rate: 6.000000
# Minibatch perplexity: 7.29
# Validation set perplexity: 6.93
# Average loss at step 2000: 1.988604 learning rate: 6.000000
# Minibatch perplexity: 7.75
# ================================================================================
# mio iros not nutorolic mallession five at are name jacks and calla struptre the p
# yvah i f forect anchilioned vilatic apped slangerrformatible isand are dectunal s
# kh heners one six four two molcax enn a sidignals to file sperack ranef bo da ove
#  endight leagerat kingsoftware capaliki dhad bactical bake aflirsh k and in how a
# gbanle gave so natly ettrepas bisting gcaldibaft ataller acadod have impley fom e
# ================================================================================
# Validation set perplexity: 6.77
# Average loss at step 2100: 1.969668 learning rate: 6.000000
# Minibatch perplexity: 6.84
# Validation set perplexity: 6.99
# Average loss at step 2200: 1.955524 learning rate: 6.000000
# Minibatch perplexity: 7.17
# Validation set perplexity: 6.94
# Average loss at step 2300: 1.965262 learning rate: 6.000000
# Minibatch perplexity: 6.79
# Validation set perplexity: 6.72
# Average loss at step 2400: 1.966402 learning rate: 6.000000
# Minibatch perplexity: 7.78
# Validation set perplexity: 7.16
# Average loss at step 2500: 1.979242 learning rate: 6.000000
# Minibatch perplexity: 7.39
# Validation set perplexity: 7.06
# Average loss at step 2600: 1.960897 learning rate: 6.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 7.01
# Average loss at step 2700: 1.982316 learning rate: 6.000000
# Minibatch perplexity: 7.07
# Validation set perplexity: 6.78
# Average loss at step 2800: 1.944431 learning rate: 6.000000
# Minibatch perplexity: 6.83
# Validation set perplexity: 6.73
# Average loss at step 2900: 1.948269 learning rate: 6.000000
# Minibatch perplexity: 6.67
# Validation set perplexity: 6.70
# Average loss at step 3000: 1.955486 learning rate: 3.600000
# Minibatch perplexity: 7.30
# ================================================================================
# jh signal biwily capily blowingly on zero one nine bm from pears by cosnation aut
# peno four five six of marny sonnine an award speoin isbn pany or fugeral cadammer
# commergely u and greek attac american mempar gahmans t arvaring blotkw kings eque
# constral efforce if biring specifer tely news other over study an ougoo samai inv
# wmilibles decome stanyyp with renigun of the minon knighte ageiriginaly will with
# ================================================================================
# Validation set perplexity: 6.71
# Average loss at step 3100: 1.940565 learning rate: 3.600000
# Minibatch perplexity: 7.63
# Validation set perplexity: 6.50
# Average loss at step 3200: 1.944981 learning rate: 3.600000
# Minibatch perplexity: 7.21
# Validation set perplexity: 6.60
# Average loss at step 3300: 1.922762 learning rate: 3.600000
# Minibatch perplexity: 6.93
# Validation set perplexity: 6.56
# Average loss at step 3400: 1.931068 learning rate: 3.600000
# Minibatch perplexity: 6.47
# Validation set perplexity: 6.58
# Average loss at step 3500: 1.930110 learning rate: 3.600000
# Minibatch perplexity: 7.62
# Validation set perplexity: 6.65
# Average loss at step 3600: 1.926971 learning rate: 3.600000
# Minibatch perplexity: 6.85
# Validation set perplexity: 6.45
# Average loss at step 3700: 1.926689 learning rate: 3.600000
# Minibatch perplexity: 6.39
# Validation set perplexity: 6.57
# Average loss at step 3800: 1.927637 learning rate: 3.600000
# Minibatch perplexity: 6.53
# Validation set perplexity: 6.41
# Average loss at step 3900: 1.919748 learning rate: 3.600000
# Minibatch perplexity: 6.78
# Validation set perplexity: 6.58
# Average loss at step 4000: 1.926092 learning rate: 3.600000
# Minibatch perplexity: 6.48
# ================================================================================
# qhnly jeawdia for althoeope in astonic festruction the kwughloeus cda uniter in t
# sjamed require seam namt by mishan varials also balywenginated ch hawestly comest
# yly nater warized work and arfmented to first chard prexercifievity of the pen si
# ihoulationer the morapimu ovemberg  ailts it fhoring very stofs pemistraity is bl
# kking groupst hargente in the armonuop scfoy pasticalkhayehas is is militiatively
# ================================================================================
# Validation set perplexity: 6.53
# Average loss at step 4100: 1.918561 learning rate: 3.600000
# Minibatch perplexity: 7.09
# Validation set perplexity: 6.64
# Average loss at step 4200: 1.909769 learning rate: 3.600000
# Minibatch perplexity: 6.59
# Validation set perplexity: 6.62
# Average loss at step 4300: 1.894033 learning rate: 3.600000
# Minibatch perplexity: 6.32
# Validation set perplexity: 6.66
# Average loss at step 4400: 1.924896 learning rate: 3.600000
# Minibatch perplexity: 7.39
# Validation set perplexity: 6.62
# Average loss at step 4500: 1.924832 learning rate: 2.160000
# Minibatch perplexity: 6.90
# Validation set perplexity: 6.62
# Average loss at step 4600: 1.926254 learning rate: 2.160000
# Minibatch perplexity: 6.96
# Validation set perplexity: 6.43
# Average loss at step 4700: 1.908132 learning rate: 2.160000
# Minibatch perplexity: 7.57
# Validation set perplexity: 6.49
# Average loss at step 4800: 1.888840 learning rate: 2.160000
# Minibatch perplexity: 7.31
# Validation set perplexity: 6.45
# Average loss at step 4900: 1.905022 learning rate: 2.160000
# Minibatch perplexity: 7.11
# Validation set perplexity: 6.53
# Average loss at step 5000: 1.921107 learning rate: 2.160000
# Minibatch perplexity: 7.19
# ================================================================================
# fy sonna and be hurdence woll did blood rgicter nation an inflann northel heir ho
# fy straition proted eyer to kall one jame earternal det or jac has ayorger dim in
# wxmjt latb speed had  a racisic other other may treaks terthim of austriance enti
# nly laitney arbord natural if article than are by which rying grant the marties l
# hp widers definee careifor belf joe river filer wavier of stremn ganower shortmen
# ================================================================================
# Validation set perplexity: 6.50
# Average loss at step 5100: 1.936854 learning rate: 2.160000
# Minibatch perplexity: 6.67
# Validation set perplexity: 6.69
# Average loss at step 5200: 1.934698 learning rate: 2.160000
# Minibatch perplexity: 6.27
# Validation set perplexity: 6.47
# Average loss at step 5300: 1.913434 learning rate: 2.160000
# Minibatch perplexity: 6.57
# Validation set perplexity: 6.47
# Average loss at step 5400: 1.912757 learning rate: 2.160000
# Minibatch perplexity: 6.38
# Validation set perplexity: 6.44
# Average loss at step 5500: 1.896825 learning rate: 2.160000
# Minibatch perplexity: 6.21
# Validation set perplexity: 6.41
# Average loss at step 5600: 1.933609 learning rate: 2.160000
# Minibatch perplexity: 7.36
# Validation set perplexity: 6.41
# Average loss at step 5700: 1.888374 learning rate: 2.160000
# Minibatch perplexity: 6.28
# Validation set perplexity: 6.33
# Average loss at step 5800: 1.888623 learning rate: 2.160000
# Minibatch perplexity: 6.84
# Validation set perplexity: 6.37
# Average loss at step 5900: 1.911364 learning rate: 2.160000
# Minibatch perplexity: 6.62
# Validation set perplexity: 6.51
# Average loss at step 6000: 1.888737 learning rate: 1.296000
# Minibatch perplexity: 6.96
# ================================================================================
# ful birdmoles whool palinus this known version thus zier first inatiational radea
# tv coloniapsy jond partted profibuted but m shistor yuose caswedlute it founders
# tg the meloogissirs ihcalends face prescours content recept where penach islaboor
# u glay naugotia tory communication two amepb the callers lactural by and smalls a
# known four three two to of mut diziluty of the other the uararlifit after make tw
# ================================================================================
# Validation set perplexity: 6.40
# Average loss at step 6100: 1.889724 learning rate: 1.296000
# Minibatch perplexity: 6.21
# Validation set perplexity: 6.45
# Average loss at step 6200: 1.918522 learning rate: 1.296000
# Minibatch perplexity: 6.93
# Validation set perplexity: 6.47
# Average loss at step 6300: 1.923260 learning rate: 1.296000
# Minibatch perplexity: 7.38
# Validation set perplexity: 6.37
# Average loss at step 6400: 1.949982 learning rate: 1.296000
# Minibatch perplexity: 6.98
# Validation set perplexity: 6.29
# Average loss at step 6500: 1.950788 learning rate: 1.296000
# Minibatch perplexity: 7.11
# Validation set perplexity: 6.26
# Average loss at step 6600: 1.908278 learning rate: 1.296000
# Minibatch perplexity: 7.01
# Validation set perplexity: 6.27
# Average loss at step 6700: 1.909577 learning rate: 1.296000
# Minibatch perplexity: 6.78
# Validation set perplexity: 6.27
# Average loss at step 6800: 1.894999 learning rate: 1.296000
# Minibatch perplexity: 6.49
# Validation set perplexity: 6.29
# Average loss at step 6900: 1.880682 learning rate: 1.296000
# Minibatch perplexity: 7.11
# Validation set perplexity: 6.27
# Average loss at step 7000: 1.907428 learning rate: 1.296000
# Minibatch perplexity: 6.47
# ================================================================================
# mw that payeforc in hpmendress from the spancal of eizes x five zero five one nin
# rvalway ien dynthe my asicalian player and undithhal refernal lecs co eight berwu
# and socity fullers is programmy psitical vionic trade celd about oztners of mongr
# zjdged transe kille phoe pown pyro his one nine six four five four hme general or
# w about thoughts of fluce bacces number not milital portice the suvery this varia
# ================================================================================
# Validation set perplexity: 6.28
# Average loss at step 7100: 1.880035 learning rate: 1.296000
# Minibatch perplexity: 6.59
# Validation set perplexity: 6.27
# Average loss at step 7200: 1.903755 learning rate: 1.296000
# Minibatch perplexity: 6.82
# Validation set perplexity: 6.24
# Average loss at step 7300: 1.912922 learning rate: 1.296000
# Minibatch perplexity: 6.50
# Validation set perplexity: 6.26
# Average loss at step 7400: 1.902799 learning rate: 1.296000
# Minibatch perplexity: 6.80
# Validation set perplexity: 6.12
# Average loss at step 7500: 1.874906 learning rate: 0.777600
# Minibatch perplexity: 5.75
# Validation set perplexity: 6.15
# Average loss at step 7600: 1.902355 learning rate: 0.777600
# Minibatch perplexity: 6.63
# Validation set perplexity: 6.19
# Average loss at step 7700: 1.895589 learning rate: 0.777600
# Minibatch perplexity: 7.18
# Validation set perplexity: 6.13
# Average loss at step 7800: 1.894989 learning rate: 0.777600
# Minibatch perplexity: 5.52
# Validation set perplexity: 6.16
# Average loss at step 7900: 1.904174 learning rate: 0.777600
# Minibatch perplexity: 6.54
# Validation set perplexity: 6.15
# Average loss at step 8000: 1.878468 learning rate: 0.777600
# Minibatch perplexity: 5.98
# ================================================================================
# qse was bitium by the movewer groups gumberbabrianslo the risionns are one or thr
# le five to from eight six roln general pxies in a is the deprelection be angepela
# ks core explding the cable europed worked with othermne in one three zero one eig
# rthewu rucks to ieguage trackr there from moust waines to moters also one seven t
# rvond ennery viplised muny only all threquhded time that the conctore ferce socia
# ================================================================================
# Validation set perplexity: 6.17
# Average loss at step 8100: 1.893140 learning rate: 0.777600
# Minibatch perplexity: 7.21
# Validation set perplexity: 6.06
# Average loss at step 8200: 1.901969 learning rate: 0.777600
# Minibatch perplexity: 6.24
# Validation set perplexity: 6.09
# Average loss at step 8300: 1.913140 learning rate: 0.777600
# Minibatch perplexity: 6.60
# Validation set perplexity: 6.12
# Average loss at step 8400: 1.894131 learning rate: 0.777600
# Minibatch perplexity: 6.98
# Validation set perplexity: 6.10
# Average loss at step 8500: 1.890227 learning rate: 0.777600
# Minibatch perplexity: 6.69
# Validation set perplexity: 6.11
# Average loss at step 8600: 1.873849 learning rate: 0.777600
# Minibatch perplexity: 5.74
# Validation set perplexity: 6.11
# Average loss at step 8700: 1.890098 learning rate: 0.777600
# Minibatch perplexity: 6.65
# Validation set perplexity: 6.10

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
