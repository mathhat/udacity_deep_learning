# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

for num_skips, skip_window in [(2, 4), (4, 8)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=12, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(12)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with num_skips = 2 and skip_window = 4:
#     batch: ['term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['of', 'first', 'a', 'originated', 'used', 'first', 'term', 'of', 'first', 'term', 'radicals', 'abuse']
#
# with num_skips = 4 and skip_window = 8:
#     batch: ['used', 'used', 'used', 'used', 'against', 'against', 'against', 'against', 'early', 'early', 'early', 'early']
#     labels: ['including', 'class', 'originated', 'anarchism', 'the', 'class', 'as', 'of', 'the', 'working', 'a', 'diggers']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.983684
# Nearest to but: antoni, languages, kryptonite, cours, formally, vieira, yuen, nb,
# Nearest to it: nicomachean, daemons, headmaster, sys, centriole, unveiling, bittersweet, mboxx,
# Nearest to one: snowflakes, faiths, adultery, condemns, deadheads, masterminded, electrophilic, txt,
# Nearest to state: spectator, cryptology, moderates, mossad, splitflag, cameroun, excerpt, sisterhood,
# Nearest to and: rake, khwarizmi, safin, arbitrage, cardinals, xix, cante, foxes,
# Nearest to this: apex, social, romanian, arrives, accrue, judaic, marinus, sho,
# Nearest to united: alarming, waw, circumscription, adjustable, blah, captives, medicines, autonegotiation,
# Nearest to which: gilberts, gomer, mobilization, dowry, legitimacy, raps, fidesz, ccitt,
# Nearest to called: deprecating, blender, untouchables, utraquists, defy, spock, quantification, expressionism,
# Nearest to years: topology, barefoot, uphold, yitzchak, satire, anselm, flintstones, ne,
# Nearest to may: lifecycle, nene, lekhanya, yetzirah, cluster, ulam, hall, dub,
# Nearest to four: jamison, candu, ballots, outdated, tudor, auteur, meant, exchanged,
# Nearest to of: kenobi, ahimelech, enumerates, fumble, contra, dnieper, manna, morum,
# Nearest to has: librarians, kilometers, hymenoptera, instructor, santander, ashcroft, mondeo, arcueil,
# Nearest to to: ingalls, olympia, monoclonal, strictest, fluidity, sst, egyptologist, settlers,
# Nearest to when: rebecca, coronado, impiety, distinguishes, capensis, discourse, ecology, wyche,
# Average loss at step 2000: 4.357823
# Average loss at step 4000: 3.860423
# Average loss at step 6000: 3.791083
# Average loss at step 8000: 3.685252
# Average loss at step 10000: 3.616048
# Nearest to but: are, bessarabia, and, calvinists, antoni, lightfoot, examining, lbs,
# Nearest to it: he, this, there, which, they, she, not, bigcup,
# Nearest to one: two, three, six, seven, five, eight, four, antinomies,
# Nearest to state: cameroun, excerpt, moderates, mossad, valued, druidry, max, spectator,
# Nearest to and: or, who, but, aeschylus, microbial, certified, converting, confession,
# Nearest to this: it, the, which, a, that, melt, confiscated, his,
# Nearest to united: circumscription, blah, captives, identity, waw, alarming, occ, plasticizers,
# Nearest to which: it, this, that, still, who, also, armoured, experiencing,
# Nearest to called: model, namo, endosymbiotic, granite, zorro, dative, resultant, fatou,
# Nearest to years: topology, satire, births, references, klaproth, preventive, unmibh, yitzchak,
# Nearest to may: can, could, ulam, colonized, denied, devon, royalists, breastfeeding,
# Nearest to four: six, three, eight, five, seven, two, nine, zero,
# Nearest to of: in, alphabetical, for, packard, provisional, during, pep, idb,
# Nearest to has: had, librarians, was, is, have, latgale, plankton, talisman,
# Nearest to to: shalt, sst, jacobean, euphrates, shay, hyperfine, bretwalda, pegs,
# Nearest to when: distinguishes, ecology, spiritualist, poses, wyche, haunt, almoravids, discourse,
# Average loss at step 12000: 3.600823
# Average loss at step 14000: 3.572620
# Average loss at step 16000: 3.412860
# Average loss at step 18000: 3.459689
# Average loss at step 20000: 3.541932
# Nearest to but: however, and, which, though, eventually, while, or, virtually,
# Nearest to it: he, there, this, which, they, she, no, not,
# Nearest to one: two, four, three, seven, six, eight, five, nine,
# Nearest to state: valued, cameroun, druidry, excerpt, moderates, portland, decorative, maximum,
# Nearest to and: or, but, bottling, crosstown, boil, through, certified, which,
# Nearest to this: it, which, the, ballot, a, that, thalberg, its,
# Nearest to united: blah, circumscription, identity, captives, zack, occ, arabs, nepeta,
# Nearest to which: who, that, this, it, but, also, there, armoured,
# Nearest to called: resultant, model, nebula, granite, however, vardar, statistic, juicy,
# Nearest to years: klaproth, preventive, sephiroth, unmibh, satire, year, topology, unsuspecting,
# Nearest to may: can, would, could, should, might, to, must, cannot,
# Nearest to four: five, seven, three, eight, six, two, nine, zero,
# Nearest to of: internalized, maharashtri, tulare, same, in, lahoud, for, baseline,
# Nearest to has: had, have, was, is, latgale, librarians, prevents, sessions,
# Nearest to to: would, could, will, may, not, can, jacobean, bretwalda,
# Nearest to when: distinguishes, after, ecology, as, solvent, if, since, reload,
# Average loss at step 22000: 3.499008
# Average loss at step 24000: 3.492876
# Average loss at step 26000: 3.475742
# Average loss at step 28000: 3.483205
# Average loss at step 30000: 3.505697
# Nearest to but: however, while, which, and, though, when, saltpeter, although,
# Nearest to it: he, there, this, she, they, which, not, who,
# Nearest to one: two, four, seven, eight, six, five, three, nine,
# Nearest to state: valued, cameroun, druidry, elements, fugues, maximum, excerpt, grievous,
# Nearest to and: or, but, abdurrahman, in, of, jyutping, which, crosstown,
# Nearest to this: it, which, that, what, tishri, another, there, aileen,
# Nearest to united: blah, circumscription, bible, arabs, identity, captives, nepeta, country,
# Nearest to which: that, this, who, but, also, wrongdoing, reinterpreted, it,
# Nearest to called: resultant, granite, protons, named, nebula, considered, model, obsolescence,
# Nearest to years: months, year, days, sephiroth, preventive, unmibh, klaproth, shovel,
# Nearest to may: can, would, could, should, might, will, must, cannot,
# Nearest to four: five, six, eight, seven, three, two, nine, one,
# Nearest to of: in, alphabetical, and, from, lahoud, for, among, including,
# Nearest to has: had, have, is, was, latgale, prevents, plankton, having,
# Nearest to to: can, would, will, could, jacobean, not, cannot, may,
# Nearest to when: if, after, since, before, where, because, but, was,
# Average loss at step 32000: 3.497133
# Average loss at step 34000: 3.495837
# Average loss at step 36000: 3.451321
# Average loss at step 38000: 3.304066
# Average loss at step 40000: 3.426268
# Nearest to but: however, while, and, though, which, although, generally, where,
# Nearest to it: he, there, she, this, they, not, which, we,
# Nearest to one: seven, two, four, six, eight, three, five, nine,
# Nearest to state: cameroun, government, decorative, valued, fugues, moderates, garlic, elements,
# Nearest to and: or, but, in, including, fortnight, though, like, elaine,
# Nearest to this: which, it, the, that, any, some, what, tishri,
# Nearest to united: blah, circumscription, bible, identity, arabs, nepeta, balkan, captives,
# Nearest to which: that, this, also, who, but, there, it, wrongdoing,
# Nearest to called: named, granite, obsolescence, protons, model, considered, forwarding, salads,
# Nearest to years: months, days, year, unmibh, sephiroth, preventive, times, births,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Nearest to four: six, three, two, five, seven, eight, nine, one,
# Nearest to of: in, from, for, including, attlee, pep, stradella, longwave,
# Nearest to has: had, have, was, is, latgale, recantation, plankton, librarians,
# Nearest to to: will, could, in, would, ingalls, must, may, cannot,
# Nearest to when: if, before, while, where, after, because, sic, distinguishes,
# Average loss at step 42000: 3.436036
# Average loss at step 44000: 3.457523
# Average loss at step 46000: 3.448607
# Average loss at step 48000: 3.356296
# Average loss at step 50000: 3.385392
# Nearest to but: however, while, and, though, although, when, where, that,
# Nearest to it: he, there, she, this, they, now, which, eventually,
# Nearest to one: two, eight, six, four, seven, five, three, nine,
# Nearest to state: national, government, fugues, decorative, states, cameroun, moderates, buckminsterfullerene,
# Nearest to and: or, but, of, in, including, who, s, corrupting,
# Nearest to this: which, it, he, the, that, some, homme, samyaksam,
# Nearest to united: blah, bible, circumscription, french, balkan, invulnerable, meanwhile, nepeta,
# Nearest to which: that, this, also, who, wrongdoing, often, there, these,
# Nearest to called: named, obsolescence, wicked, model, known, granite, used, suppressing,
# Nearest to years: days, months, year, times, unsuspecting, centuries, unmibh, springer,
# Nearest to may: can, would, could, might, will, must, should, cannot,
# Nearest to four: six, five, eight, three, seven, two, nine, zero,
# Nearest to of: in, and, reboot, packard, including, astor, algal, alphabetical,
# Nearest to has: had, have, was, is, prevents, distrusted, villa, sharkey,
# Nearest to to: olympia, could, would, astonishingly, rhombicuboctahedron, should, fiery, cannot,
# Nearest to when: if, while, before, after, where, although, though, against,
# Average loss at step 52000: 3.431941
# Average loss at step 54000: 3.425708
# Average loss at step 56000: 3.438133
# Average loss at step 58000: 3.395993
# Average loss at step 60000: 3.395797
# Nearest to but: however, and, although, though, see, than, which, gish,
# Nearest to it: there, he, she, this, now, they, that, farc,
# Nearest to one: eight, four, two, seven, three, six, five, nine,
# Nearest to state: government, town, city, national, stock, fugues, decorative, cameroun,
# Nearest to and: or, but, although, including, see, tca, in, which,
# Nearest to this: which, it, that, the, there, some, however, erhard,
# Nearest to united: blah, circumscription, bible, balkan, french, southern, constitution, invulnerable,
# Nearest to which: that, this, however, nor, what, these, wrongdoing, but,
# Nearest to called: wicked, named, used, considered, known, obsolescence, model, natal,
# Nearest to years: days, months, year, times, centuries, seconds, hours, unsuspecting,
# Nearest to may: can, would, could, might, will, should, must, cannot,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to of: in, for, comprehensive, although, same, including, tulare, with,
# Nearest to has: had, have, was, is, having, although, seems, latgale,
# Nearest to to: olympia, would, monoclonal, conectiva, rhombicuboctahedron, astonishingly, ingalls, cannot,
# Nearest to when: if, before, while, after, although, though, where, because,
# Average loss at step 62000: 3.240928
# Average loss at step 64000: 3.259691
# Average loss at step 66000: 3.408486
# Average loss at step 68000: 3.393810
# Average loss at step 70000: 3.363017
# Nearest to but: however, though, although, and, while, tds, generally, which,
# Nearest to it: he, she, there, this, they, we, still, you,
# Nearest to one: two, seven, six, four, eight, three, five, nine,
# Nearest to state: states, city, government, national, fugues, decorative, hampstead, cameroun,
# Nearest to and: or, but, which, like, while, manifest, undeveloped, looters,
# Nearest to this: which, it, the, another, there, some, that, what,
# Nearest to united: blah, bible, circumscription, balkan, french, disrupted, optics, eyewitness,
# Nearest to which: that, this, also, what, and, these, but, who,
# Nearest to called: named, used, considered, wicked, known, straightforward, model, granite,
# Nearest to years: days, months, year, centuries, times, seconds, hours, decades,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to of: including, although, algal, constitutes, comprehensive, haddock, like, in,
# Nearest to has: had, have, is, was, sharkey, having, dull, riddled,
# Nearest to to: will, would, monoclonal, could, jacobean, ingalls, cannot, can,
# Nearest to when: if, before, while, where, because, though, after, although,
# Average loss at step 72000: 3.378700
# Average loss at step 74000: 3.349167
# Average loss at step 76000: 3.320489
# Average loss at step 78000: 3.352907
# Average loss at step 80000: 3.377008
# Nearest to but: however, while, although, though, and, than, trichomes, gish,
# Nearest to it: he, she, there, this, they, we, usually, not,
# Nearest to one: seven, six, two, three, eight, four, five, nine,
# Nearest to state: city, states, government, national, town, cameroun, governor, kingdom,
# Nearest to and: or, but, while, including, than, bake, inoculation, intrigued,
# Nearest to this: it, which, another, itself, the, there, that, some,
# Nearest to united: blah, circumscription, bible, balkan, french, brightness, invulnerable, eyewitness,
# Nearest to which: that, this, also, wrongdoing, typically, reinterpreted, who, often,
# Nearest to called: named, known, considered, used, straightforward, wicked, firearm, granite,
# Nearest to years: days, months, year, centuries, times, hours, minutes, seconds,
# Nearest to may: can, would, could, must, will, should, might, cannot,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to of: in, including, baseline, lahoud, entire, andries, although, analyst,
# Nearest to has: had, have, is, was, although, having, steeple, dull,
# Nearest to to: olympia, shay, monoclonal, ingalls, cannot, radii, will, rhombicuboctahedron,
# Nearest to when: before, if, though, after, although, while, where, during,
# Average loss at step 82000: 3.407096
# Average loss at step 84000: 3.411944
# Average loss at step 86000: 3.395055
# Average loss at step 88000: 3.349974
# Average loss at step 90000: 3.362608
# Nearest to but: however, and, although, while, though, they, he, she,
# Nearest to it: he, she, there, this, they, probably, we, itself,
# Nearest to one: seven, two, four, six, eight, five, three, nine,
# Nearest to state: city, national, government, senate, states, optionally, chapman, governor,
# Nearest to and: or, but, while, berry, subpage, remediation, jyutping, however,
# Nearest to this: it, which, another, the, itself, some, erhard, he,
# Nearest to united: blah, circumscription, balkan, bible, eyewitness, brightness, constitution, optics,
# Nearest to which: that, this, also, wrongdoing, what, who, usually, often,
# Nearest to called: named, used, known, considered, straightforward, referred, wicked, hailed,
# Nearest to years: days, months, centuries, year, decades, hours, minutes, seconds,
# Nearest to may: can, could, must, might, would, will, should, cannot,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to of: for, including, in, baseline, under, netting, and, exact,
# Nearest to has: had, have, is, was, having, since, dull, socket,
# Nearest to to: olympia, ingalls, monoclonal, would, will, fiery, euphrates, shay,
# Nearest to when: if, before, while, though, where, although, after, because,
# Average loss at step 92000: 3.394414
# Average loss at step 94000: 3.254883
# Average loss at step 96000: 3.352451
# Average loss at step 98000: 3.244043
# Average loss at step 100000: 3.358328
# Nearest to but: however, although, and, though, while, which, generally, drivetrain,
# Nearest to it: he, she, this, there, they, probably, now, which,
# Nearest to one: two, seven, four, five, six, eight, three, nine,
# Nearest to state: city, government, national, states, governor, decorative, subset, procter,
# Nearest to and: or, but, like, when, vassar, although, while, of,
# Nearest to this: it, which, another, itself, some, repressions, syndication, what,
# Nearest to united: circumscription, balkan, blah, bible, eyewitness, optics, lionheart, brightness,
# Nearest to which: that, this, wrongdoing, these, usually, but, what, typically,
# Nearest to called: named, known, used, straightforward, referred, zander, considered, hailed,
# Nearest to years: days, months, year, centuries, decades, hours, seconds, times,
# Nearest to may: can, could, must, might, should, would, will, cannot,
# Nearest to four: seven, six, eight, five, three, nine, two, zero,
# Nearest to of: including, dnieper, in, constitutes, and, from, original, although,
# Nearest to has: had, have, is, was, since, having, steeple, villa,
# Nearest to to: will, olympia, monoclonal, shay, can, could, must, jacobean,
# Nearest to when: if, while, though, before, where, although, after, during,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list  
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

for bag_window in [2,4 ]:
    data_index = 0
    batch, labels = generate_batch(batch_size=12, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch[0]])
    print('    labels:', [reverse_dictionary[li] for li in labels[0]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with bag_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term']
#     labels: ['as']
#
# with bag_window = 4:
#     batch: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     labels: ['term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*bag_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs= tf.reduce_sum(embed,1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(0.7).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.887705
# Nearest to called: bri, sealed, likely, complain, sur, lehi, crafted, steadfastly,
# Nearest to nine: nicol, acl, fours, nuances, nosed, blower, opencyc, neutron,
# Nearest to these: conclusions, adonis, ul, haganah, unclaimed, rdenas, contract, accumulates,
# Nearest to american: paranoid, ibf, tarim, resurfaced, poignant, webern, trucks, claypool,
# Nearest to four: endocytosis, explanation, conquers, formed, prelate, reuter, traitors, violate,
# Nearest to other: grizzly, tutu, booster, vanuatu, ehrlich, gustave, interglacial, liechtenstein,
# Nearest to would: kinase, assist, clearest, tutti, patent, copernicus, beelzebub, agrippina,
# Nearest to zero: charlatans, rooster, heart, perfecting, presidents, albrecht, wasp, departments,
# Nearest to or: cheshire, mathbb, brian, hairdresser, hesitated, suetonius, guanine, klein,
# Nearest to a: met, mf, motorised, clergy, femininity, tunings, petitions, hobbit,
# Nearest to by: tinbergen, diaries, centrally, guts, robson, enforcing, imperator, satrapy,
# Nearest to were: terran, adversity, cr, corrie, stricture, ontario, seizures, fart,
# Nearest to only: interlingua, zuma, koza, exhausting, blume, railway, punts, shock,
# Nearest to this: timbres, lun, traditional, espoused, reentry, volunteer, ebirah, cliath,
# Nearest to for: desmo, starships, tonk, trespass, z, charley, securing, crunch,
# Nearest to six: robbery, everyone, theirs, files, couper, capybaras, bcpl, depending,
# Average loss at step 2000: 4.143949
# Average loss at step 4000: 3.564408
# Average loss at step 6000: 3.506166
# Average loss at step 8000: 3.290519
# Average loss at step 10000: 3.117114
# Nearest to called: undetectable, overwrite, crafted, eugenius, intimidating, samir, popov, sealed,
# Nearest to nine: eight, six, seven, five, four, zero, three, two,
# Nearest to these: reassessment, hindered, tarnished, tsunami, myra, other, conclusions, waas,
# Nearest to american: paranoid, intv, mauryan, resurfaced, rounder, domain, beluga, homogenous,
# Nearest to four: six, seven, eight, five, nine, three, zero, two,
# Nearest to other: tutu, unilateral, liechtenstein, voiceover, these, embattled, bono, haw,
# Nearest to would: can, will, may, could, plum, should, to, perceptive,
# Nearest to zero: five, six, eight, four, seven, nine, three, cosmopolitan,
# Nearest to or: and, than, cooling, insurrections, kumasi, moabites, prospective, supranational,
# Nearest to a: the, met, any, lyle, crack, tees, terminus, democratically,
# Nearest to by: bo, cylinders, evolutionary, childhood, nugent, as, hyphae, have,
# Nearest to were: are, was, have, be, had, trafford, is, corrie,
# Nearest to only: koza, livingston, zuma, interlingua, ibiblio, angrily, lolita, bangs,
# Nearest to this: it, which, emptiness, the, masada, cmi, boosted, that,
# Nearest to for: dissociative, instrumentalists, at, spelled, own, iambic, envelopment, to,
# Nearest to six: eight, seven, nine, four, five, three, zero, two,
# Average loss at step 12000: 3.143596
# Average loss at step 14000: 3.238834
# Average loss at step 16000: 3.073050
# Average loss at step 18000: 3.128419
# Average loss at step 20000: 3.172801
# Nearest to called: undetectable, marbles, produced, deutscher, ostrich, eugenius, mimics, overwrite,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to these: some, several, such, many, clockwise, all, hindered, their,
# Nearest to american: resurfaced, english, gentleman, mauryan, intv, qadhafi, acheson, s,
# Nearest to four: five, six, seven, eight, three, nine, zero, two,
# Nearest to other: liechtenstein, tutu, cao, aggressor, voiceover, some, haw, many,
# Nearest to would: will, can, could, may, should, plum, to, must,
# Nearest to zero: five, eight, six, four, seven, nine, three, lamarckian,
# Nearest to or: and, than, cooling, insurrections, climactic, amstrad, kary, pnh,
# Nearest to a: the, crack, another, abiogenesis, mf, terminus, resistance, aut,
# Nearest to by: cylinders, bo, insecurity, against, tinbergen, childhood, imperator, when,
# Nearest to were: are, have, was, had, be, rainforest, include, preclear,
# Nearest to only: livingston, koza, concoction, zuma, newcomer, not, stemmed, sphinx,
# Nearest to this: which, it, that, the, emptiness, irreversible, another, what,
# Nearest to for: against, dissociative, phone, unflattering, gaiman, franchisor, with, of,
# Nearest to six: five, four, eight, seven, nine, three, zero, two,
# Average loss at step 22000: 3.057409
# Average loss at step 24000: 3.033838
# Average loss at step 26000: 3.017726
# Average loss at step 28000: 2.933805
# Average loss at step 30000: 2.952075
# Nearest to called: undetectable, shrine, marbles, overwrite, mimics, popov, ostrich, deutscher,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to these: several, some, many, such, clockwise, which, hindered, all,
# Nearest to american: canadian, british, resurfaced, intv, english, acheson, gentleman, irish,
# Nearest to four: seven, six, five, eight, three, nine, zero, two,
# Nearest to other: various, different, many, liechtenstein, singing, haw, hyperion, newington,
# Nearest to would: will, can, could, may, should, might, must, plum,
# Nearest to zero: four, five, six, seven, eight, three, nine, two,
# Nearest to or: and, than, climactic, com, kary, ahimelech, feininger, but,
# Nearest to a: another, abiogenesis, the, tees, any, crack, terminus, mr,
# Nearest to by: against, for, bo, sasaki, accountable, with, honesty, insecurity,
# Nearest to were: are, was, had, have, be, is, became, being,
# Nearest to only: gears, skylab, graal, apostol, minefields, stemmed, angers, livingston,
# Nearest to this: which, it, the, any, what, another, emptiness, irreversible,
# Nearest to for: dissociative, phone, while, during, after, by, gaiman, in,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Average loss at step 32000: 2.980523
# Average loss at step 34000: 2.977827
# Average loss at step 36000: 3.005147
# Average loss at step 38000: 2.980545
# Average loss at step 40000: 2.841255
# Nearest to called: cryptographic, shrine, mimics, marbles, ostrich, produced, considered, xenosaga,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to these: several, some, many, such, clockwise, both, they, hindered,
# Nearest to american: british, irish, english, canadian, resurfaced, german, persuasion, verizon,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to other: various, different, cao, aggressor, newington, eaton, endpoint, wheel,
# Nearest to would: will, could, can, may, should, might, must, does,
# Nearest to zero: seven, eight, five, four, six, nine, three, lamarckian,
# Nearest to or: and, than, kary, equidistant, robins, kumasi, summarised, cooling,
# Nearest to a: the, another, iwama, any, bridgeport, terminus, abiogenesis, akkad,
# Nearest to by: cylinders, bo, insecurity, entrances, under, when, beneath, shakur,
# Nearest to were: are, was, have, had, be, include, became, been,
# Nearest to only: stemmed, pelvic, not, twayne, calvin, first, lemons, graal,
# Nearest to this: which, it, that, any, what, irreversible, fsf, paleocene,
# Nearest to for: dissociative, against, unflattering, phone, after, onion, hermas, while,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Average loss at step 42000: 2.963662
# Average loss at step 44000: 2.929689
# Average loss at step 46000: 2.920423
# Average loss at step 48000: 2.930498
# Average loss at step 50000: 2.917272
# Nearest to called: known, cryptographic, considered, used, produced, ostrich, deutscher, mimics,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to these: some, such, several, many, both, those, clockwise, they,
# Nearest to american: irish, italiana, english, british, australian, italian, indian, german,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to other: various, different, aggressor, others, newington, singing, shroud, many,
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to zero: five, six, eight, four, seven, nine, three, lamarckian,
# Nearest to or: and, than, kary, uvs, hereafter, commuters, kumasi, climactic,
# Nearest to a: the, another, nellie, cmp, hurts, abiogenesis, tees, any,
# Nearest to by: cylinders, bo, insecurity, under, using, with, sinti, medgar,
# Nearest to were: are, have, was, had, been, be, include, became,
# Nearest to only: reinterpreted, first, parliamentary, stemmed, last, normally, elegance, concoction,
# Nearest to this: which, it, what, that, the, there, subpixels, fsf,
# Nearest to for: dissociative, unflattering, morbidity, phone, webcomics, crunch, when, goblins,
# Nearest to six: eight, four, five, seven, nine, three, zero, two,
# Average loss at step 52000: 2.705590
# Average loss at step 54000: 2.908377
# Average loss at step 56000: 2.892405
# Average loss at step 58000: 2.884862
# Average loss at step 60000: 2.838900
# Nearest to called: known, cryptographic, considered, named, see, kept, mimics, produced,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to these: such, some, those, several, many, both, clockwise, which,
# Nearest to american: british, italiana, persuasion, canadian, indian, irish, australian, german,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to other: various, different, others, older, aggressor, singing, embattled, newington,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to zero: seven, six, five, eight, four, nine, three, two,
# Nearest to or: and, while, kolbe, than, collegium, iiis, kary, insurrections,
# Nearest to a: another, the, cmp, hammadi, continually, interwiki, enough, abiogenesis,
# Nearest to by: cylinders, bo, iommi, when, sinti, efnet, through, sasaki,
# Nearest to were: are, was, have, had, became, include, be, been,
# Nearest to only: reinterpreted, first, last, normally, concoction, encounter, pelvic, stemmed,
# Nearest to this: which, it, the, what, emmer, schooling, there, emptiness,
# Nearest to for: against, when, dissociative, franchisor, hermas, during, after, starships,
# Nearest to six: seven, eight, five, four, three, nine, two, zero,
# Average loss at step 62000: 2.917573
# Average loss at step 64000: 2.894235
# Average loss at step 66000: 2.868115
# Average loss at step 68000: 2.828428
# Average loss at step 70000: 2.798065
# Nearest to called: named, known, cryptographic, considered, used, pnh, ostrich, produced,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to these: some, many, several, those, such, which, both, clockwise,
# Nearest to american: british, canadian, australian, german, italian, italiana, indian, qadhafi,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to other: various, others, different, newington, older, aggressor, shroud, gateless,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to zero: five, seven, six, four, eight, three, nine, two,
# Nearest to or: and, collegium, than, niccolo, optimize, courting, kolbe, twister,
# Nearest to a: the, another, any, abiogenesis, enough, cmp, nellie, iwama,
# Nearest to by: through, cylinders, bo, when, iommi, efnet, using, under,
# Nearest to were: are, was, have, had, include, those, capitolina, became,
# Nearest to only: still, concoction, pelvic, normally, always, twayne, actually, no,
# Nearest to this: it, which, some, emmer, what, communicative, fsf, any,
# Nearest to for: dissociative, while, including, when, after, against, kelvin, franchisor,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Average loss at step 72000: 2.856978
# Average loss at step 74000: 2.827833
# Average loss at step 76000: 2.775109
# Average loss at step 78000: 2.760475
# Average loss at step 80000: 2.802293
# Nearest to called: named, known, considered, used, cryptographic, referred, eudes, pnh,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to these: several, those, many, some, such, which, both, all,
# Nearest to american: australian, british, canadian, italian, indian, irish, german, italiana,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to other: various, others, shroud, different, aggressor, older, newington, individual,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to zero: five, seven, six, four, eight, three, nine, lamarckian,
# Nearest to or: and, than, niccolo, equidistant, insurrections, though, pruitt, pnh,
# Nearest to a: another, the, cmp, nellie, abiogenesis, spoilers, akkad, terminus,
# Nearest to by: through, cylinders, iommi, beneath, efnet, hyphae, laurent, insecurity,
# Nearest to were: are, was, had, have, those, became, been, capitolina,
# Nearest to only: still, concoction, minimal, always, reinterpreted, already, normally, encounter,
# Nearest to this: it, which, what, the, some, emmer, communicative, heuvelmans,
# Nearest to for: dissociative, franchisor, phone, against, plugins, including, after, hermas,
# Nearest to six: seven, five, eight, four, nine, three, zero, two,
# Average loss at step 82000: 2.808150
# Average loss at step 84000: 2.723304
# Average loss at step 86000: 2.750380
# Average loss at step 88000: 2.720770
# Average loss at step 90000: 2.736000
# Nearest to called: named, considered, cryptographic, known, referred, ostrich, xenosaga, pnh,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to these: those, some, several, many, such, which, both, certain,
# Nearest to american: australian, canadian, british, italian, indian, irish, italiana, german,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to other: various, others, older, newington, shroud, trace, many, individual,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to or: and, than, commuters, feininger, stallions, collegium, any, abelard,
# Nearest to a: another, the, any, enough, hammadi, abiogenesis, akkad, spoilers,
# Nearest to by: through, without, efnet, cylinders, when, iommi, including, entrances,
# Nearest to were: are, was, have, had, include, been, those, capitolina,
# Nearest to only: concoction, reinterpreted, twayne, already, minimal, still, both, always,
# Nearest to this: it, which, the, what, paleocene, emmer, some, godless,
# Nearest to for: after, dissociative, although, against, hermas, franchisor, during, immorality,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Average loss at step 92000: 2.778323
# Average loss at step 94000: 2.638313
# Average loss at step 96000: 2.799268
# Average loss at step 98000: 2.809884
# Average loss at step 100000: 2.762751
# Nearest to called: named, considered, cryptographic, referred, known, pnh, eudes, termed,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to these: those, several, some, many, which, both, certain, such,
# Nearest to american: australian, canadian, british, italian, indian, irish, german, african,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to other: various, others, shroud, older, individual, newington, many, trace,
# Nearest to would: will, could, can, might, should, may, must, cannot,
# Nearest to zero: six, five, seven, eight, four, nine, three, two,
# Nearest to or: and, than, kary, though, collegium, feininger, commuters, insurrections,
# Nearest to a: another, enough, the, cmp, abiogenesis, spoilers, any, hammadi,
# Nearest to by: through, cylinders, including, efnet, during, using, with, malan,
# Nearest to were: are, was, have, had, include, those, been, capitolina,
# Nearest to only: concoction, already, actually, twayne, still, both, always, apostol,
# Nearest to this: which, it, emmer, pds, what, some, that, godless,
# Nearest to for: after, when, although, including, phone, dissociative, unflattering, while,
# Nearest to six: seven, five, eight, four, nine, three, zero, two,

# %%
num_points = 600

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
